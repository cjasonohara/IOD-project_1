# %%
#Import Numpy, Pandas, and Matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Using Pandas, read the data from the CSV file
data = pd.read_csv('imdb_top_1000.csv')

# %%
#Convert to a Pandas DataFrame
df = pd.DataFrame(data)

# %%
#Perform Exploratory Data Analysis
#1. Display the first 5 rows
print(df.head())
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
#Check out the Shape of the DataFrame
df.shape
# Out:
# (1000, 16)

# %%
#Create a new Index Column for the DataFrame
df['Index'] = np.arange(1, 1001)
df.set_index('Index', inplace=True)
df.head()
# Out:
#                                              Poster_Link  \
# Index
# 1      https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2      https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3      https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4      https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5      https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                    Series_Title Released_Year Certificate  Runtime  \
# Index
# 1      The Shawshank Redemption          1994           A  142 min
# 2                 The Godfather          1972           A  175 min
# 3               The Dark Knight          2008          UA  152 min
# 4        The Godfather: Part II          1974           A  202 min
# 5                  12 Angry Men          1957           U   96 min
#
#                       Genre  IMDB_Rating  \
# Index
# 1                     Drama          9.3
# 2              Crime, Drama          9.2
# 3      Action, Crime, Drama          9.0
# 4              Crime, Drama          9.0
# 5              Crime, Drama          9.0
#
#                                                 Overview  Meta_score  \
# Index
# 1      Two imprisoned men bond over a number of years...        80.0
# 2      An organized crime dynasty's aging patriarch t...       100.0
# 3      When the menace known as the Joker wreaks havo...        84.0
# 4      The early life and career of Vito Corleone in ...        90.0
# 5      A jury holdout attempts to prevent a miscarria...        96.0
#
#                    Director           Star1           Star2          Star3  \
# Index
# 1            Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 2      Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 3         Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 4      Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 5              Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#                 Star4  No_of_Votes        Gross
# Index
# 1      William Sadler      2343110   28,341,469
# 2        Diane Keaton      1620367  134,966,411
# 3       Michael Caine      2303232  534,858,444
# 4        Diane Keaton      1129952   57,300,000
# 5        John Fiedler       689845    4,360,000

# %%
#Look at the Data Types of the Columns
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
#Get a description about the DataFrame numerical values
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
#What are the values in the 'Genre' column?
df['Genre'].value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %%
#Using a For Loop, get the unique values in the 'Genre' column
genres = []
for genre in df['Genre']:
    if genre not in genres:
        genres.append(genre)
genres
# Out:
# ['Drama',
#  'Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Biography, Drama, History',
#  'Action, Adventure, Sci-Fi',
#  'Drama, Romance',
#  'Western',
#  'Action, Sci-Fi',
#  'Biography, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Comedy, Drama, Thriller',
#  'Adventure, Drama, Sci-Fi',
#  'Animation, Adventure, Family',
#  'Drama, War',
#  'Crime, Drama, Fantasy',
#  'Comedy, Drama, Romance',
#  'Crime, Drama, Mystery',
#  'Crime, Drama, Thriller',
#  'Action, Drama, Mystery',
#  'Drama, Family, Fantasy',
#  'Drama, Music',
#  'Biography, Comedy, Drama',
#  'Drama, Mystery, Sci-Fi',
#  'Biography, Drama, Music',
#  'Crime, Mystery, Thriller',
#  'Animation, Adventure, Drama',
#  'Animation, Drama, War',
#  'Adventure, Comedy, Sci-Fi',
#  'Horror, Mystery, Thriller',
#  'Drama, Romance, War',
#  'Comedy, Drama, Family',
#  'Animation, Drama, Fantasy',
#  'Action, Biography, Drama',
#  'Animation, Action, Adventure',
#  'Drama, Western',
#  'Action, Adventure',
#  'Comedy, Drama',
#  'Drama, Family',
#  'Drama, Mystery, Thriller',
#  'Mystery, Thriller',
#  'Drama, Horror',
#  'Drama, Mystery, War',
#  'Horror, Sci-Fi',
#  'Drama, Musical',
#  'Comedy',
#  'Drama, Film-Noir',
#  'Comedy, Drama, War',
#  'Drama, Thriller, War',
#  'Drama, Fantasy, Horror',
#  'Crime, Drama, Music',
#  'Adventure, Drama, War',
#  'Drama, Romance, Sci-Fi',
#  'Comedy, Romance',
#  'Comedy, Crime',
#  'Drama, Family, Sport',
#  'Animation, Adventure, Comedy',
#  'Adventure, Drama, Thriller',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Adventure, Biography, Drama',
#  'Adventure, Mystery, Thriller',
#  'Mystery, Romance, Thriller',
#  'Comedy, Musical, Romance',
#  'Crime, Drama, Film-Noir',
#  'Drama, Mystery',
#  'Drama, Sci-Fi',
#  'Action, Drama, War',
#  'Action, Drama',
#  'Adventure, Comedy, Drama',
#  'Biography, Drama, Sport',
#  'Action, Comedy, Crime',
#  'Action, Biography, Crime',
#  'Drama, Mystery, Romance',
#  'Action, Drama, Sport',
#  'Drama, Fantasy, War',
#  'Action, Drama, Sci-Fi',
#  'Biography, Drama',
#  'Action, Comedy, Romance',
#  'Animation, Family, Fantasy',
#  'Action, Thriller',
#  'Action, Adventure, Comedy',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Drama, History',
#  'Action, Drama, Thriller',
#  'Comedy, Music, Romance',
#  'Drama, Fantasy, History',
#  'Crime, Thriller',
#  'Adventure, Drama, Western',
#  'Comedy, War',
#  'Drama, Thriller',
#  'Animation, Drama, Family',
#  'Drama, Romance, Thriller',
#  'Comedy, Drama, Musical',
#  'Comedy, Drama, Fantasy',
#  'Adventure, Comedy, Crime',
#  'Adventure, Drama, Fantasy',
#  'Biography, Drama, Family',
#  'Animation, Comedy, Drama',
#  'Drama, Sport',
#  'Animation, Action, Drama',
#  'Adventure, Drama, Musical',
#  'Drama, Music, Romance',
#  'Comedy, Crime, Romance',
#  'Comedy, Crime, Sport',
#  'Drama, History, Romance',
#  'Adventure, Drama',
#  'Animation, Adventure, Fantasy',
#  'Horror, Mystery, Sci-Fi',
#  'Drama, Fantasy, Music',
#  'Action, Sci-Fi, Thriller',
#  'Drama, Fantasy',
#  'Drama, Horror, Thriller',
#  'Drama, History',
#  'Film-Noir, Mystery, Thriller',
#  'Fantasy, Horror, Mystery',
#  'Action, Crime, Thriller',
#  'Comedy, Drama, Music',
#  'Biography, Drama, Thriller',
#  'Animation, Biography, Drama',
#  'Action, Mystery, Thriller',
#  'Crime, Drama, Romance',
#  'Action, Adventure, Thriller',
#  'Crime, Drama, Musical',
#  'Animation, Crime, Mystery',
#  'Action, Crime, Comedy',
#  'Mystery, Sci-Fi, Thriller',
#  'Animation, Action, Crime',
#  'Comedy, Fantasy, Romance',
#  'Drama, History, Thriller',
#  'Animation, Action, Sci-Fi',
#  'Adventure, Family, Fantasy',
#  'Drama, Fantasy, Romance',
#  'Drama, History, War',
#  'Adventure, Thriller',
#  'Horror',
#  'Drama, Family, Musical',
#  'Action, Drama, Western',
#  'Crime, Drama, Horror',
#  'Drama, Film-Noir, Mystery',
#  'Comedy, Crime, Thriller',
#  'Film-Noir, Mystery',
#  'Comedy, Crime, Mystery',
#  'Drama, Fantasy, Mystery',
#  'Comedy, Horror',
#  'Action, Adventure, History',
#  'Drama, Music, Mystery',
#  'Comedy, Music',
#  'Comedy, Family',
#  'Drama, Music, Musical',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Biography',
#  'Biography, Drama, War',
#  'Action, Adventure, Western',
#  'Horror, Thriller',
#  'Comedy, Mystery, Romance',
#  'Drama, Thriller, Western',
#  'Crime, Film-Noir, Thriller',
#  'Drama, Film-Noir, Romance',
#  'Crime, Film-Noir, Mystery',
#  'Action, Adventure, Romance',
#  'Comedy, Music, Musical',
#  'Adventure, Horror, Sci-Fi',
#  'Fantasy, Horror',
#  'Action, Drama, History',
#  'Adventure, Comedy, Family',
#  'Animation, Biography, Crime',
#  'Adventure, Biography, Crime',
#  'Adventure, Fantasy',
#  'Drama, History, Mystery',
#  'Action, Comedy, Mystery',
#  'Adventure, Drama, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, History',
#  'Action, Comedy, Fantasy',
#  'Family, Sci-Fi',
#  'Adventure, History, War',
#  'Animation, Sci-Fi',
#  'Family, Fantasy, Musical',
#  'Thriller',
#  'Comedy, Family, Fantasy',
#  'Adventure, Comedy, Film-Noir',
#  'Film-Noir, Thriller',
#  'Comedy, Family, Romance',
#  'Drama, Horror, Sci-Fi',
#  'Comedy, Musical, War',
#  'Biography, Drama, Romance',
#  'Drama, History, Music',
#  'Animation, Action, Fantasy',
#  'Animation, Comedy, Fantasy',
#  'Comedy, Western',
#  'Action, Adventure, War',
#  'Drama, Horror, Mystery',
#  'Animation, Comedy, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Mystery',
#  'Action, Adventure, Family',
#  'Action, Crime, Mystery',
#  'Animation, Drama, Romance',
#  'Drama, War, Western',
#  'Adventure, Comedy, War']

# %%
#Get the value names, in the 'Genre' column
What are the unique values in the 'Genre' column?
df['Genre'].unique()
# Out:
# Object `column` not found.
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
#        'Animation, Action, Adventure', 'Drama, Western',
#        'Action, Adventure', 'Comedy, Drama', 'Drama, Family',
#        'Drama, Mystery, Thriller', 'Mystery, Thriller', 'Drama, Horror',
#        'Drama, Mystery, War', 'Horror, Sci-Fi', 'Drama, Musical',
#        'Comedy', 'Drama, Film-Noir', 'Comedy, Drama, War',
#        'Drama, Thriller, War', 'Drama, Fantasy, Horror',
#        'Crime, Drama, Music', 'Adventure, Drama, War',
#        'Drama, Romance, Sci-Fi', 'Comedy, Romance', 'Comedy, Crime',
#        'Drama, Family, Sport', 'Animation, Adventure, Comedy',
#        'Adventure, Drama, Thriller', 'Comedy, Crime, Drama',
#        'Crime, Drama, Sci-Fi', 'Adventure, Sci-Fi',
#        'Adventure, Biography, Drama', 'Adventure, Mystery, Thriller',
#        'Mystery, Romance, Thriller', 'Comedy, Musical, Romance',
#        'Crime, Drama, Film-Noir', 'Drama, Mystery', 'Drama, Sci-Fi',
#        'Action, Drama, War', 'Action, Drama', 'Adventure, Comedy, Drama',
#        'Biography, Drama, Sport', 'Action, Comedy, Crime',
#        'Action, Biography, Crime', 'Drama, Mystery, Romance',
#        'Action, Drama, Sport', 'Drama, Fantasy, War',
#        'Action, Drama, Sci-Fi', 'Biography, Drama',
#        'Action, Comedy, Romance', 'Animation, Family, Fantasy',
#        'Action, Thriller', 'Action, Adventure, Comedy',
#        'Adventure, Comedy, Fantasy', 'Adventure, Drama, History',
#        'Action, Drama, Thriller', 'Comedy, Music, Romance',
#        'Drama, Fantasy, History', 'Crime, Thriller',
#        'Adventure, Drama, Western', 'Comedy, War', 'Drama, Thriller',
#        'Animation, Drama, Family', 'Drama, Romance, Thriller',
#        'Comedy, Drama, Musical', 'Comedy, Drama, Fantasy',
#        'Adventure, Comedy, Crime', 'Adventure, Drama, Fantasy',
#        'Biography, Drama, Family', 'Animation, Comedy, Drama',
#        'Drama, Sport', 'Animation, Action, Drama',
#        'Adventure, Drama, Musical', 'Drama, Music, Romance',
#        'Comedy, Crime, Romance', 'Comedy, Crime, Sport',
#        'Drama, History, Romance', 'Adventure, Drama',
#        'Animation, Adventure, Fantasy', 'Horror, Mystery, Sci-Fi',
#        'Drama, Fantasy, Music', 'Action, Sci-Fi, Thriller',
#        'Drama, Fantasy', 'Drama, Horror, Thriller', 'Drama, History',
#        'Film-Noir, Mystery, Thriller', 'Fantasy, Horror, Mystery',
#        'Action, Crime, Thriller', 'Comedy, Drama, Music',
#        'Biography, Drama, Thriller', 'Animation, Biography, Drama',
#        'Action, Mystery, Thriller', 'Crime, Drama, Romance',
#        'Action, Adventure, Thriller', 'Crime, Drama, Musical',
#        'Animation, Crime, Mystery', 'Action, Crime, Comedy',
#        'Mystery, Sci-Fi, Thriller', 'Animation, Action, Crime',
#        'Comedy, Fantasy, Romance', 'Drama, History, Thriller',
#        'Animation, Action, Sci-Fi', 'Adventure, Family, Fantasy',
#        'Drama, Fantasy, Romance', 'Drama, History, War',
#        'Adventure, Thriller', 'Horror', 'Drama, Family, Musical',
#        'Action, Drama, Western', 'Crime, Drama, Horror',
#        'Drama, Film-Noir, Mystery', 'Comedy, Crime, Thriller',
#        'Film-Noir, Mystery', 'Comedy, Crime, Mystery',
#        'Drama, Fantasy, Mystery', 'Comedy, Horror',
#        'Action, Adventure, History', 'Drama, Music, Mystery',
#        'Comedy, Music', 'Comedy, Family', 'Drama, Music, Musical',
#        'Action, Adventure, Horror', 'Action, Adventure, Biography',
#        'Biography, Drama, War', 'Action, Adventure, Western',
#        'Horror, Thriller', 'Comedy, Mystery, Romance',
#        'Drama, Thriller, Western', 'Crime, Film-Noir, Thriller',
#        'Drama, Film-Noir, Romance', 'Crime, Film-Noir, Mystery',
#        'Action, Adventure, Romance', 'Comedy, Music, Musical',
#        'Adventure, Horror, Sci-Fi', 'Fantasy, Horror',
#        'Action, Drama, History', 'Adventure, Comedy, Family',
#        'Animation, Biography, Crime', 'Adventure, Biography, Crime',
#        'Adventure, Fantasy', 'Drama, History, Mystery',
#        'Action, Comedy, Mystery', 'Adventure, Drama, Romance',
#        'Drama, Sci-Fi, Thriller', 'Crime, Drama, History',
#        'Action, Comedy, Fantasy', 'Family, Sci-Fi',
#        'Adventure, History, War', 'Animation, Sci-Fi',
#        'Family, Fantasy, Musical', 'Thriller', 'Comedy, Family, Fantasy',
#        'Adventure, Comedy, Film-Noir', 'Film-Noir, Thriller',
#        'Comedy, Family, Romance', 'Drama, Horror, Sci-Fi',
#        'Comedy, Musical, War', 'Biography, Drama, Romance',
#        'Drama, History, Music', 'Animation, Action, Fantasy',
#        'Animation, Comedy, Fantasy', 'Comedy, Western',
#        'Action, Adventure, War', 'Drama, Horror, Mystery',
#        'Animation, Comedy, Crime', 'Action, Adventure, Crime',
#        'Action, Adventure, Mystery', 'Action, Adventure, Family',
#        'Action, Crime, Mystery', 'Animation, Drama, Romance',
#        'Drama, War, Western', 'Adventure, Comedy, War'], dtype=object)

# %%
#Sort the dataframe by the 'Genre' column
df.sort_values(by='Genre')
# Out:
#                                              Poster_Link  \
# Index
# 169    https://m.media-amazon.com/images/M/MV5BMjNkMz...
# 156    https://m.media-amazon.com/images/M/MV5BOTY4Yj...
# 73     https://m.media-amazon.com/images/M/MV5BMjA0OD...
# 841    https://m.media-amazon.com/images/M/MV5BODBmOW...
# 64     https://m.media-amazon.com/images/M/MV5BMTk4OD...
# ...                                                  ...
# 701    https://m.media-amazon.com/images/M/MV5BMTQyNT...
# 13     https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 49     https://m.media-amazon.com/images/M/MV5BZGI5Mj...
# 692    https://m.media-amazon.com/images/M/MV5BMjIxND...
# 116    https://m.media-amazon.com/images/M/MV5BNWM1Nm...
#
#                              Series_Title Released_Year Certificate  Runtime  \
# Index
# 169    Indiana Jones and the Last Crusade          1989           U  127 min
# 156                         Batman Begins          2005          UA  140 min
# 73                Raiders of the Lost Ark          1981           A  115 min
# 841                           First Blood          1982           A   93 min
# 64                  The Dark Knight Rises          2012          UA  164 min
# ...                                   ...           ...         ...      ...
# 701                       Wait Until Dark          1967         NaN  108 min
# 13        Il buono, il brutto, il cattivo          1966           A  161 min
# 49           Once Upon a Time in the West          1968           U  165 min
# 692                The Outlaw Josey Wales          1976           A  135 min
# 116            Per qualche dollaro in più          1965           U  132 min
#
#                    Genre  IMDB_Rating  \
# Index
# 169    Action, Adventure          8.2
# 156    Action, Adventure          8.2
# 73     Action, Adventure          8.4
# 841    Action, Adventure          7.7
# 64     Action, Adventure          8.4
# ...                  ...          ...
# 701             Thriller          7.8
# 13               Western          8.8
# 49               Western          8.5
# 692              Western          7.8
# 116              Western          8.3
#
#                                                 Overview  Meta_score  \
# Index
# 169    In 1938, after his father Professor Henry Jone...        65.0
# 156    After training with his mentor, Batman begins ...        70.0
# 73     In 1936, archaeologist and adventurer Indiana ...        85.0
# 841    A veteran Green Beret is forced by a cruel She...        61.0
# 64     Eight years after the Joker's reign of anarchy...        78.0
# ...                                                  ...         ...
# 701    A recently blinded woman is terrorized by a tr...        81.0
# 13     A bounty hunting scam joins two men in an unea...        90.0
# 49     A mysterious stranger with a harmonica joins f...        80.0
# 692    Missouri farmer Josey Wales joins a Confederat...        69.0
# 116    Two bounty hunters with the same intentions te...        74.0
#
#                 Director               Star1            Star2  \
# Index
# 169     Steven Spielberg       Harrison Ford     Sean Connery
# 156    Christopher Nolan      Christian Bale    Michael Caine
# 73      Steven Spielberg       Harrison Ford      Karen Allen
# 841         Ted Kotcheff  Sylvester Stallone    Brian Dennehy
# 64     Christopher Nolan      Christian Bale        Tom Hardy
# ...                  ...                 ...              ...
# 701        Terence Young      Audrey Hepburn       Alan Arkin
# 13          Sergio Leone      Clint Eastwood      Eli Wallach
# 49          Sergio Leone         Henry Fonda  Charles Bronson
# 692       Clint Eastwood      Clint Eastwood     Sondra Locke
# 116         Sergio Leone      Clint Eastwood    Lee Van Cleef
#
#                     Star3                Star4  No_of_Votes        Gross
# Index
# 169          Alison Doody      Denholm Elliott       692366  197,171,806
# 156          Ken Watanabe          Liam Neeson      1308302  206,852,432
# 73           Paul Freeman     John Rhys-Davies       884112  248,159,971
# 841        Richard Crenna        Bill McKinney       226541   47,212,904
# 64          Anne Hathaway          Gary Oldman      1516346  448,139,099
# ...                   ...                  ...          ...          ...
# 701        Richard Crenna  Efrem Zimbalist Jr.        27733   17,550,741
# 13          Lee Van Cleef         Aldo Giuffrè       688390    6,100,000
# 49      Claudia Cardinale        Jason Robards       302844    5,321,508
# 692      Chief Dan George        Bill McKinney        65659   31,800,000
# 116    Gian Maria Volontè           Mara Krupp       232772   15,000,000
#
# [1000 rows x 16 columns]

# %%
#Drop the 'Poster_Link' column
df.drop('Poster_Link', axis=1, inplace=True)
df.head()
# Out:
#                    Series_Title Released_Year Certificate  Runtime  \
# Index
# 1      The Shawshank Redemption          1994           A  142 min
# 2                 The Godfather          1972           A  175 min
# 3               The Dark Knight          2008          UA  152 min
# 4        The Godfather: Part II          1974           A  202 min
# 5                  12 Angry Men          1957           U   96 min
#
#                       Genre  IMDB_Rating  \
# Index
# 1                     Drama          9.3
# 2              Crime, Drama          9.2
# 3      Action, Crime, Drama          9.0
# 4              Crime, Drama          9.0
# 5              Crime, Drama          9.0
#
#                                                 Overview  Meta_score  \
# Index
# 1      Two imprisoned men bond over a number of years...        80.0
# 2      An organized crime dynasty's aging patriarch t...       100.0
# 3      When the menace known as the Joker wreaks havo...        84.0
# 4      The early life and career of Vito Corleone in ...        90.0
# 5      A jury holdout attempts to prevent a miscarria...        96.0
#
#                    Director           Star1           Star2          Star3  \
# Index
# 1            Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 2      Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 3         Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 4      Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 5              Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#                 Star4  No_of_Votes        Gross
# Index
# 1      William Sadler      2343110   28,341,469
# 2        Diane Keaton      1620367  134,966,411
# 3       Michael Caine      2303232  534,858,444
# 4        Diane Keaton      1129952   57,300,000
# 5        John Fiedler       689845    4,360,000

# %%
#Drop the 'Overview' column
df.drop('Overview', axis=1, inplace=True)
df.head()
# Out:
#                    Series_Title Released_Year Certificate  Runtime  \
# Index
# 1      The Shawshank Redemption          1994           A  142 min
# 2                 The Godfather          1972           A  175 min
# 3               The Dark Knight          2008          UA  152 min
# 4        The Godfather: Part II          1974           A  202 min
# 5                  12 Angry Men          1957           U   96 min
#
#                       Genre  IMDB_Rating  Meta_score              Director  \
# Index
# 1                     Drama          9.3        80.0        Frank Darabont
# 2              Crime, Drama          9.2       100.0  Francis Ford Coppola
# 3      Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 4              Crime, Drama          9.0        90.0  Francis Ford Coppola
# 5              Crime, Drama          9.0        96.0          Sidney Lumet
#
#                 Star1           Star2          Star3           Star4  \
# Index
# 1         Tim Robbins  Morgan Freeman     Bob Gunton  William Sadler
# 2       Marlon Brando       Al Pacino     James Caan    Diane Keaton
# 3      Christian Bale    Heath Ledger  Aaron Eckhart   Michael Caine
# 4           Al Pacino  Robert De Niro  Robert Duvall    Diane Keaton
# 5         Henry Fonda     Lee J. Cobb  Martin Balsam    John Fiedler
#
#        No_of_Votes        Gross
# Index
# 1          2343110   28,341,469
# 2          1620367  134,966,411
# 3          2303232  534,858,444
# 4          1129952   57,300,000
# 5           689845    4,360,000

# %%
#I don't need the sub-genres in the 'Genre' column, so will need to pull out the main genre from the 'Genre' column
#Create a new column with the first (main) category in the 'Genre' column values
df['Genre'] = df['Genre'].astype(str)  # Ensure the column is a string
df['main_genre'] = df['Genre'].str.split(',').str[0]  # Extract all characters before the first comma
df.head()
# Out:
#                    Series_Title Released_Year Certificate  Runtime  \
# Index
# 1      The Shawshank Redemption          1994           A  142 min
# 2                 The Godfather          1972           A  175 min
# 3               The Dark Knight          2008          UA  152 min
# 4        The Godfather: Part II          1974           A  202 min
# 5                  12 Angry Men          1957           U   96 min
#
#                       Genre  IMDB_Rating  Meta_score              Director  \
# Index
# 1                     Drama          9.3        80.0        Frank Darabont
# 2              Crime, Drama          9.2       100.0  Francis Ford Coppola
# 3      Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 4              Crime, Drama          9.0        90.0  Francis Ford Coppola
# 5              Crime, Drama          9.0        96.0          Sidney Lumet
#
#                 Star1           Star2          Star3           Star4  \
# Index
# 1         Tim Robbins  Morgan Freeman     Bob Gunton  William Sadler
# 2       Marlon Brando       Al Pacino     James Caan    Diane Keaton
# 3      Christian Bale    Heath Ledger  Aaron Eckhart   Michael Caine
# 4           Al Pacino  Robert De Niro  Robert Duvall    Diane Keaton
# 5         Henry Fonda     Lee J. Cobb  Martin Balsam    John Fiedler
#
#        No_of_Votes        Gross main_genre
# Index
# 1          2343110   28,341,469      Drama
# 2          1620367  134,966,411      Crime
# 3          2303232  534,858,444     Action
# 4          1129952   57,300,000      Crime
# 5           689845    4,360,000      Crime

# %%
#Drop the following columns: 'Certificate', 'Director', 'Star1', 'Star2', 'Star3', 'Star4'
df.drop(['Certificate', 'Director', 'Star1', 'Star2', 'Star3', 'Star4'], axis=1, inplace=True)
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre
# Index
# 1              9.3        80.0      2343110   28,341,469      Drama
# 2              9.2       100.0      1620367  134,966,411      Crime
# 3              9.0        84.0      2303232  534,858,444     Action
# 4              9.0        90.0      1129952   57,300,000      Crime
# 5              9.0        96.0       689845    4,360,000      Crime

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# No_of_Votes        0
# Gross            169
# main_genre         0
# dtype: int64

# %%
#Calculate the percentage of missing values in Metascore and Gross columns
missing_metascore = (157/1000) * 100
missing_gross = (169/1000) * 100
print(missing_metascore, missing_gross)
# Out:
# 15.7 16.900000000000002

# %%
#View the missing values in the 'Meta_score' column
df[df['Meta_score'].isnull()]
# Out:
#                         Series_Title Released_Year  Runtime  \
# Index
# 21                   Soorarai Pottru          2020  153 min
# 55         Ayla: The Daughter of War          2017  125 min
# 56                      Vikram Vedha          2017  147 min
# 58                            Dangal          2016  161 min
# 66                  Taare Zameen Par          2007  165 min
# ...                              ...           ...      ...
# 873    The Day the Earth Stood Still          1951   92 min
# 875                            Gilda          1946  110 min
# 900                        El cuerpo          2012  112 min
# 910                        Celda 211          2009  113 min
# 914                        Die Welle          2008  107 min
#
#                            Genre  IMDB_Rating  Meta_score  No_of_Votes  \
# Index
# 21                         Drama          8.6         NaN        54995
# 55     Biography, Drama, History          8.4         NaN        34112
# 56          Action, Crime, Drama          8.4         NaN        28401
# 58      Action, Biography, Drama          8.4         NaN       156479
# 66                 Drama, Family          8.4         NaN       168895
# ...                          ...          ...         ...          ...
# 873                Drama, Sci-Fi          7.7         NaN        76315
# 875    Drama, Film-Noir, Romance          7.7         NaN        27991
# 900            Mystery, Thriller          7.6         NaN        57549
# 910     Action, Adventure, Crime          7.6         NaN        63882
# 914              Drama, Thriller          7.6         NaN       102742
#
#             Gross main_genre
# Index
# 21            NaN      Drama
# 55            NaN  Biography
# 56            NaN     Action
# 58     12,391,761     Action
# 66      1,223,869      Drama
# ...           ...        ...
# 873           NaN      Drama
# 875           NaN      Drama
# 900           NaN    Mystery
# 910           NaN     Action
# 914           NaN      Drama
#
# [157 rows x 9 columns]

# %%
#Replace the missing values in the 'Meta_score' column with the mean of the column
df['Meta_score'].fillna(df['Meta_score'].mean(), inplace=True)
df.isnull().sum()
# Out:
# /var/folders/gr/0cyzht9j16g818rxhk08kvnr0000gn/T/ipykernel_50419/2816364454.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Meta_score'].fillna(df['Meta_score'].mean(), inplace=True)
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score         0
# No_of_Votes        0
# Gross            169
# main_genre         0
# dtype: int64

# %%
#Drop the rows with missing values in the 'Gross' column
df.dropna(subset=['Gross'], inplace=True)
df.isnull().sum()
# Out:
# Series_Title     0
# Released_Year    0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Meta_score       0
# No_of_Votes      0
# Gross            0
# main_genre       0
# dtype: int64

# %%
#View the shape of the DataFrame
df.shape
# Out:
# (831, 9)

# %%
#View the first 5 rows of the DataFrame
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre
# Index
# 1              9.3        80.0      2343110   28,341,469      Drama
# 2              9.2       100.0      1620367  134,966,411      Crime
# 3              9.0        84.0      2303232  534,858,444     Action
# 4              9.0        90.0      1129952   57,300,000      Crime
# 5              9.0        96.0       689845    4,360,000      Crime

# %%
#Bring in the 'avg_ticket_price-by_yr' file
avg_ticket_price = pd.read_csv('avg_ticket_price-by_yr.csv')

# %%
#Convert avg_ticket_price to a DataFrame
avg_ticket_price_df = pd.DataFrame(avg_ticket_price)
avg_ticket_price_df.head()
# Out:
#    YEAR WORLDWIDE(US)    US             UK  AUS CHINA   EU FRANCE HONG KONG  \
# 0  1950           NaN  0.46  £0.08 ($0.22)  NaN   NaN  NaN    NaN       NaN
# 1  1951           NaN  0.53  £0.08 ($0.22)  NaN   NaN  NaN    NaN       NaN
# 2  1952           NaN  0.57  £0.08 ($0.22)  NaN   NaN  NaN    NaN       NaN
# 3  1953           NaN  0.60  £0.08 ($0.22)  NaN   NaN  NaN    NaN       NaN
# 4  1954           NaN  0.45  £0.09 ($0.25)  NaN   NaN  NaN    NaN       NaN
#
#   INDIA JAPAN  UAE            USSR/RUSSIA
# 0   NaN   NaN  NaN  1.75 Rbls[60] ($0.33)
# 1   NaN   NaN  NaN                    NaN
# 2   NaN   NaN  NaN                    NaN
# 3   NaN   NaN  NaN                    NaN
# 4   NaN   NaN  NaN                    NaN

# %%
#Drop the following columns from the avg_ticket_price_df: 'WORLDWIDE(US)', 'UK', 'AUS', 'CHINA', 'EU', 'FRANCE', 'HONG KONG', 'INDIA', 'JAPAN', 'UAE', 'USSR/RUSSIA'
avg_ticket_price_df.drop(['WORLDWIDE(US)', 'UK', 'AUS', 'CHINA', 'EU', 'FRANCE', 'HONG KONG', 'INDIA', 'JAPAN', 'UAE', 'USSR/RUSSIA'], axis=1, inplace=True)
avg_ticket_price_df.head()
# Out:
#    YEAR    US
# 0  1950  0.46
# 1  1951  0.53
# 2  1952  0.57
# 3  1953  0.60
# 4  1954  0.45

# %%
print(df.columns)
print(avg_ticket_price_df.columns)
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Meta_score', 'No_of_Votes', 'Gross', 'main_genre'],
#       dtype='object')
# Index(['YEAR', 'US'], dtype='object')

# %%
#Using the 'YEAR' column in the avg_ticket_price_df and the 'Realeased_Year' column in the df, create a new column 'avg_ticket' in the df that shows the average ticket price for each movie
df['avg_ticket'] = df['Released_Year'].map(avg_ticket_price_df.set_index('YEAR')['US'])
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre  \
# Index
# 1              9.3        80.0      2343110   28,341,469      Drama
# 2              9.2       100.0      1620367  134,966,411      Crime
# 3              9.0        84.0      2303232  534,858,444     Action
# 4              9.0        90.0      1129952   57,300,000      Crime
# 5              9.0        96.0       689845    4,360,000      Crime
#
#        avg_ticket
# Index
# 1            4.18
# 2            1.70
# 3            7.18
# 4            1.87
# 5            0.51

# %%
#Review to validate the new column
avg_ticket_price_df.head(40)
# Out:
#     YEAR    US
# 0   1950  0.46
# 1   1951  0.53
# 2   1952  0.57
# 3   1953  0.60
# 4   1954  0.45
# 5   1955  0.48
# 6   1956  0.50
# 7   1957  0.51
# 8   1958  0.51
# 9   1959  0.51
# 10  1960  0.60
# 11  1961  0.69
# 12  1962  0.70
# 13  1963  0.85
# 14  1964  0.93
# 15  1965  1.01
# 16  1966  1.09
# 17  1967  1.20
# 18  1968  1.31
# 19  1969  1.42
# 20  1970  1.55
# 21  1971  1.65
# 22  1972  1.70
# 23  1973  1.77
# 24  1974  1.87
# 25  1975  2.05
# 26  1976  2.13
# 27  1977  2.23
# 28  1978  2.34
# 29  1979  2.51
# 30  1980  2.69
# 31  1981  2.78
# 32  1982  2.94
# 33  1983  3.15
# 34  1984  3.36
# 35  1985  3.55
# 36  1986  3.71
# 37  1987  3.91
# 38  1988  4.11
# 39  1989  3.97

# %%
#Convert the 'Gross' column to a float
df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre  \
# Index
# 1              9.3        80.0      2343110   28341469.0      Drama
# 2              9.2       100.0      1620367  134966411.0      Crime
# 3              9.0        84.0      2303232  534858444.0     Action
# 4              9.0        90.0      1129952   57300000.0      Crime
# 5              9.0        96.0       689845    4360000.0      Crime
#
#        avg_ticket
# Index
# 1            4.18
# 2            1.70
# 3            7.18
# 4            1.87
# 5            0.51

# %%
#Create a new column that divides the 'Gross' column by the 'avg_ticket' column
df['Tickets_Sold'] = df['Gross'] / df['avg_ticket']
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre  \
# Index
# 1              9.3        80.0      2343110   28341469.0      Drama
# 2              9.2       100.0      1620367  134966411.0      Crime
# 3              9.0        84.0      2303232  534858444.0     Action
# 4              9.0        90.0      1129952   57300000.0      Crime
# 5              9.0        96.0       689845    4360000.0      Crime
#
#        avg_ticket  Tickets_Sold
# Index
# 1            4.18  6.780256e+06
# 2            1.70  7.939201e+07
# 3            7.18  7.449282e+07
# 4            1.87  3.064171e+07
# 5            0.51  8.549020e+06

# %%
#Format the 'Tickets_Sold' column to 2 decimal places
df['Tickets_Sold'] = df['Tickets_Sold'].round(2)
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994  142 min                 Drama
# 2                 The Godfather          1972  175 min          Crime, Drama
# 3               The Dark Knight          2008  152 min  Action, Crime, Drama
# 4        The Godfather: Part II          1974  202 min          Crime, Drama
# 5                  12 Angry Men          1957   96 min          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre  \
# Index
# 1              9.3        80.0      2343110   28341469.0      Drama
# 2              9.2       100.0      1620367  134966411.0      Crime
# 3              9.0        84.0      2303232  534858444.0     Action
# 4              9.0        90.0      1129952   57300000.0      Crime
# 5              9.0        96.0       689845    4360000.0      Crime
#
#        avg_ticket  Tickets_Sold
# Index
# 1            4.18    6780255.74
# 2            1.70   79392006.47
# 3            7.18   74492819.50
# 4            1.87   30641711.23
# 5            0.51    8549019.61

# %%
#Get the unique values in the 'main_genre' column
df['main_genre'].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Family', 'Thriller'], dtype=object)

# %%
#Get the mean IMDb rating for each main genre
df.groupby('main_genre')['IMDB_Rating'].mean()
# Out:
# main_genre
# Action       7.948227
# Adventure    7.936066
# Animation    7.922388
# Biography    7.925316
# Comedy       7.900781
# Crime        8.021505
# Drama        7.949145
# Family       7.800000
# Film-Noir    8.050000
# Horror       7.930000
# Mystery      8.066667
# Thriller     7.800000
# Western      8.350000
# Name: IMDB_Rating, dtype: float64

# %%
#Get the mean Meta Score for each main genre
df.groupby('main_genre')['Meta_score'].mean()
# Out:
# main_genre
# Action       73.692814
# Adventure    77.588764
# Animation    81.655442
# Biography    76.301635
# Comedy       78.081712
# Crime        76.888800
# Drama        78.693540
# Family       79.000000
# Film-Noir    96.500000
# Horror       79.300000
# Mystery      76.771451
# Thriller     81.000000
# Western      78.250000
# Name: Meta_score, dtype: float64

# %%
#Visualize the mean IMDb rating for each main genre
df.groupby('main_genre')['IMDB_Rating'].mean().plot(kind='bar')
plt.ylabel('IMDB Rating')
plt.title('Mean IMDb Rating for Each Main Genre')
plt.show()

# %%
#Get the minimum IMDb rating for each main genre
df.groupby('main_genre')['IMDB_Rating'].min()
# Out:
# main_genre
# Action       7.6
# Adventure    7.6
# Animation    7.6
# Biography    7.6
# Comedy       7.6
# Crime        7.6
# Drama        7.6
# Family       7.8
# Film-Noir    8.0
# Horror       7.6
# Mystery      7.6
# Thriller     7.8
# Western      7.8
# Name: IMDB_Rating, dtype: float64

# %%
#Get the maximum IMDb rating for each main genre
df.groupby('main_genre')['IMDB_Rating'].max()
# Out:
# main_genre
# Action       9.0
# Adventure    8.6
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.2
# Drama        9.3
# Family       7.8
# Film-Noir    8.1
# Horror       8.5
# Mystery      8.4
# Thriller     7.8
# Western      8.8
# Name: IMDB_Rating, dtype: float64

# %%
#Convert "Runtime' type to integer
df['Runtime'] = df['Runtime'].str.replace(' min', '').astype(int)

# %%
#Get the minimum runtime for each main genre
df.groupby('main_genre')['Runtime'].min()
# Out:
# main_genre
# Action        45
# Adventure     88
# Animation     71
# Biography     98
# Comedy        68
# Crime         81
# Drama         75
# Family       100
# Film-Noir    100
# Horror        91
# Mystery      100
# Thriller     108
# Western      132
# Name: Runtime, dtype: int64

# %%
#Get the maximum runtime for each main genre
df.groupby('main_genre')['Runtime'].max()
# Out:
# main_genre
# Action       207
# Adventure    228
# Animation    137
# Biography    209
# Comedy       188
# Crime        229
# Drama        242
# Family       115
# Film-Noir    104
# Horror       122
# Mystery      138
# Thriller     108
# Western      165
# Name: Runtime, dtype: int64

# %%
#Visualize the std of the runtime for each main genre
df.groupby('main_genre')['Runtime'].std().plot(kind='bar')
plt.ylabel('Runtime')
plt.title('Standard Deviation of Runtime for Each Main Genre')
plt.show()

# %%
#Use a scatter plot to show the relationship between the runtime and main genre
df.plot.scatter(x='Runtime', y='main_genre')
plt.xlabel('Runtime')
plt.ylabel('Main Genre')
plt.title('Relationship between Runtime and Main Genre')
plt.show()

# %%
#Use a scatter plot to show the relationship between the IMDb rating and runtime
df.plot.scatter(x='IMDB_Rating', y='Runtime')
plt.xlabel('IMDB Rating')
plt.ylabel('Runtime')
plt.title('Relationship between IMDb Rating and Runtime')
plt.show()

# %%
#Use a scatter plot to show the relationship between the Meta Score and runtime
df.plot.scatter(x='Meta_score', y='Runtime')
plt.xlabel('Meta Score')
plt.ylabel('Runtime')
plt.title('Relationship between Meta Score and Runtime')
plt.show()

# %%
#Use a scatter plot to show the relationship between the Meta_score and IMDb_Rating
df.plot.scatter(x='Meta_score', y='IMDB_Rating')
plt.xlabel('Meta Score')
plt.ylabel('IMDB Rating')
plt.title('Relationship between Meta Score and IMDb Rating')
plt.show()

# %%
#Calculate the correlation between the Meta_score and IMDb_Rating
df['Meta_score'].corr(df['IMDB_Rating'])
# Out:
# 0.27578103146808797

# %%
#Calculate the correlation between the Meta_score and Runtime
df['Meta_score'].corr(df['Runtime'])
# Out:
# -0.009876324084430954

# %%
#Calculate the correlation between the IMDb_Rating and Runtime
df['IMDB_Rating'].corr(df['Runtime'])
# Out:
# 0.24675641214088503

# %%
#calculate the correlation between the Tickets_Sold and Runtime
df['Tickets_Sold'].corr(df['Runtime'])
# Out:
# 0.1889851301339285

# %%
#calculate the correlation between the Tickets_Sold and Meta_score
df['Tickets_Sold'].corr(df['Meta_score'])
# Out:
# 0.07747317859121305

# %%
#calculate the correlation between the Tickets_Sold and IMDb_Rating
df['Tickets_Sold'].corr(df['IMDB_Rating'])
# Out:
# 0.17364346426039645

# %%
#Visualize df using a pairplot
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
#Normalize the 'IMDB_Rating', 'Meta_score', 'Tickets_Sold', 'No_of_Votes' columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['IMDB_Rating', 'Meta_score', 'Tickets_Sold', 'No_of_Votes']] = scaler.fit_transform(df[['IMDB_Rating', 'Meta_score', 'Tickets_Sold', 'No_of_Votes']])
df.head()
# Out:
#                    Series_Title Released_Year  Runtime                 Genre  \
# Index
# 1      The Shawshank Redemption          1994      142                 Drama
# 2                 The Godfather          1972      175          Crime, Drama
# 3               The Dark Knight          2008      152  Action, Crime, Drama
# 4        The Godfather: Part II          1974      202          Crime, Drama
# 5                  12 Angry Men          1957       96          Crime, Drama
#
#        IMDB_Rating  Meta_score  No_of_Votes        Gross main_genre  \
# Index
# 1         1.000000    0.722222     1.000000   28341469.0      Drama
# 2         0.941176    1.000000     0.688207  134966411.0      Crime
# 3         0.823529    0.777778     0.982797  534858444.0     Action
# 4         0.823529    0.861111     0.476641   57300000.0      Crime
# 5         0.823529    0.944444     0.286778    4360000.0      Crime
#
#        avg_ticket  Tickets_Sold
# Index
# 1            4.18      0.036164
# 2            1.70      0.423469
# 3            7.18      0.397337
# 4            1.87      0.163439
# 5            0.51      0.045599

# %%
#Visualize the mean relationship between main genre and IMDb_Rating
df.groupby('main_genre')['IMDB_Rating'].mean().plot(kind='bar')
plt.ylabel('IMDB Rating')
plt.title('Mean IMDb Rating for Each Main Genre')
plt.show()

# %%
#Visualize the mean relationship between main genre and Meta_score
df.groupby('main_genre')['Meta_score'].mean().plot(kind='bar')
plt.ylabel('Meta Score')
plt.title('Mean Meta Score for Each Main Genre')
plt.show()

# %%
#visualize the mean relationship between main genre and no_of_votes
df.groupby('main_genre')['No_of_Votes'].mean().plot(kind='bar')
plt.ylabel('No of Votes')
plt.title('Mean No of Votes for Each Main Genre')
plt.show()

# %%
#Visualize the mean relationship between main genre and Tickets_Sold
df.groupby('main_genre')['Tickets_Sold'].mean().plot(kind='bar')
plt.ylabel('Tickets Sold')
plt.title('Mean Tickets Sold for Each Main Genre')
plt.show()

# %%
#Visualize the median relationship between main genre and IMDb_Rating
df.groupby('main_genre')['IMDB_Rating'].median().plot(kind='bar')
plt.ylabel('IMDB Rating')
plt.title('Median IMDb Rating for Each Main Genre')
plt.show()

# %%
#Visualize the median relationship between main genre and Meta_score
df.groupby('main_genre')['Meta_score'].median().plot(kind='bar')
plt.ylabel('Meta Score')
plt.title('Median Meta Score for Each Main Genre')
plt.show()

# %%
#Visualize the median relationship between main genre and No_of_Votes
df.groupby('main_genre')['No_of_Votes'].median().plot(kind='bar')
plt.ylabel('No of Votes')
plt.title('Median No of Votes for Each Main Genre')
plt.show()

# %%
#Visualize the median relationship between main genre and Tickets_Sold
df.groupby('main_genre')['Tickets_Sold'].median().plot(kind='bar')
plt.ylabel('Tickets Sold')
plt.title('Median Tickets Sold for Each Main Genre')
plt.show()

# %%
#Extract the following columns into a new dataframe: 'IMDB_Rating', 'Meta_score', 'Main_Genre', 'Tickets_Sold', 'No_of_Votes'
df_new = df[['IMDB_Rating', 'Meta_score', 'main_genre', 'Tickets_Sold', 'No_of_Votes']]
df_new.head()
# Out:
#        IMDB_Rating  Meta_score main_genre  Tickets_Sold  No_of_Votes
# Index
# 1         1.000000    0.722222      Drama      0.036164     1.000000
# 2         0.941176    1.000000      Crime      0.423469     0.688207
# 3         0.823529    0.777778     Action      0.397337     0.982797
# 4         0.823529    0.861111      Crime      0.163439     0.476641
# 5         0.823529    0.944444      Crime      0.045599     0.286778

# %%
#Visualize this new DataFrame using a pairplot
sns.pairplot(df_new)
plt.show()

# %%
#Visualize the outliers of main_genre, using the 'IMDB_Rating' column
sns.boxplot(x='main_genre', y='IMDB_Rating', data=df)
plt.ylabel('IMDB Rating')
plt.title('Outliers of Main Genre')
plt.show()

# %%
#Visualize the outliers of main_genre, using the 'Meta_score' column
sns.boxplot(x='main_genre', y='Meta_score', data=df)
plt.ylabel('Meta Score')
plt.title('Outliers of Main Genre')
plt.show()

# %%
#Visualize the outliers of main_genre, using the 'Tickets_Sold' column
sns.boxplot(x='main_genre', y='Tickets_Sold', data=df)
plt.ylabel('Tickets Sold')
plt.title('Outliers of Main Genre')
plt.show()

# %%
#Visualize the outliers of main_genre, using the 'No_of_Votes' column
sns.boxplot(x='main_genre', y='No_of_Votes', data=df)
plt.ylabel('No of Votes')
plt.title('Outliers of Main Genre')
plt.show()
